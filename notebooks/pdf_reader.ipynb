# %%
from docling.document_converter import DocumentConverter

source = "../documents/p17.pdf"
converter = DocumentConverter()
doc = converter.convert(source).document


# print(doc.export_to_markdown())

# %%
from pathlib import Path

md_text = doc.export_to_markdown()
Path("../markdowns/p17.md").write_text(md_text)
# Out:
# 1583741

# %%
source = "../documents/f1040.pdf"
converter = DocumentConverter()
doc = converter.convert(source).document
md_text = doc.export_to_markdown()
Path("../markdowns/1040.md").write_text(md_text)
# Out:
# 11842

# %%
source = "/Users/kntc847/Downloads/w2-2025.pdf"
converter = DocumentConverter()
doc = converter.convert(source).document
md_text = doc.export_to_markdown()
Path("../personal/w2.md").write_text(md_text)
# Out:
# 16609
